# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Hands-on Lab: Create your Jupyter Notebook

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# *Exercise 2 - Create a markdown cell with the title of the notebook.*
# # Tools of data science

# %% [markdown]
# *Exercise 3 - Create a markdown cell for an introduction.*
#
# in this notebook I will show you all tools you need to become data science

# %% [markdown]
# *Exercise 4 - Create a markdown cell to list data science languages*
#
# - python
# - R
# - java
# - julia
# - scala
# - SQL
# - Javascript

# %% [markdown]
# *Exercise 5 - Create a markdown cell to list data science libraries.*
# data science libraries
# - pandas
# - numpy
# - matplotlib
# - scikit learn
# - tensorFlow
# - PyTorch

# %% [markdown]
# *Exercise 7 - Create a markdown cell introducing arithmetic expression examples. (1 pt)*
#
# | Data Science tools    | description |
# | -------- | ------- |
# | git  | for version control    |
# | github | for managing collaboration in single repo     |
# | vscode    | code editor    |

# %% [markdown]
# *Exercise 8 - Create a code cell to multiply and add numbers.*

# %%
## multiply and add numbers
print((20+5)*10)
# Out:
# 250

# %% [markdown]
# *Exercise 9 - Create a code cell to convert minutes to hours.*

# %%
## convert minutes to hour :

minutes=input('type numbers of minutes that you want to convert to hour ')

print("minutes input :"+minutes+"")
print('numbers of hours based on minutes :')
hours=int(minutes)/60
print(hours," hour")
# Out:
# minutes input :140
# numbers of hours based on minutes :
# 2.3333333333333335  hour

# %% [markdown]
# *Exercise 10 -Insert a markdown cell to list Objectives.*
#
# Below the introduction cell created in Exercise 3, insert a new markdown cell to list the objectives that this notebook covered (i.e. some of the key takeaways from the course). In this new cell start with an introductory line titled: Objectives: in bold font. Then using an unordered list (bullets) indicate 3 to 5 items covered in this notebook, such as List popular languages for Data Science.

# %% [markdown]
# *Exercise 11 - Create a markdown cell to indicate the Author’s name.*
#
#
# ### Author :
# Mohammed Ali

# %% [markdown]
# Copyright ©2024 IBM Corporation. All rights reserved.
